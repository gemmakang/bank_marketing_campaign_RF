# %% [markdown]
# <a href="https://colab.research.google.com/github/gemmakang/bank_marketing_compaign_RF/blob/master/Bank_Marketing_Campaign_with_RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc7a4829-f1b5-46e4-9ac9-236e0ae66b67" name="files[]" multiple disabled />
#      <output id="result-bc7a4829-f1b5-46e4-9ac9-236e0ae66b67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank-additional-full.csv to bank-additional-full.csv

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
# Load Data

df=pd.read_csv("bank-additional-full.csv",delimiter=";", converters={'martical':str,'education':str,'job':str,'month':str,'day_of_week':str,'y': str,'contact':str,'loan':str,'housing':str,'default':str,'poutcome':str,'age': int},engine='python')
df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
# missing value check

df.count()
# Out:
# age               41188
# job               41188
# marital           41188
# education         41188
# default           41188
# housing           41188
# loan              41188
# contact           41188
# month             41188
# day_of_week       41188
# duration          41188
# campaign          41188
# pdays             41188
# previous          41188
# poutcome          41188
# emp.var.rate      41188
# cons.price.idx    41188
# cons.conf.idx     41188
# euribor3m         41188
# nr.employed       41188
# y                 41188
# dtype: int64

# %%
# convert categoricalvariable to numerical 1 and 0
df.y=df.y.replace(to_replace=['no', 'yes'], value=[0, 1])
df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed  y
# 0   56  housemaid  married  ...     4.857      5191.0  0
# 1   57   services  married  ...     4.857      5191.0  0
# 2   37   services  married  ...     4.857      5191.0  0
# 3   40     admin.  married  ...     4.857      5191.0  0
# 4   56   services  married  ...     4.857      5191.0  0
#
# [5 rows x 21 columns]

# %%
# Explore distribution of opening deposit
values=df['y'].value_counts()
names=['No', 'Yes']
plt.figure(figsize=(6, 3))

plt.subplot()
plt.bar(names, values)

plt.suptitle('Deposit Plotting')
plt.show()

# %% [markdown]
# **Explore Numeric variables**

# %%
# Visualize correlation
correlation = df.corr()
correlation.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col1 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col2 {
#             background-color:  #f4f3f8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col3 {
#             background-color:  #c2c3df;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col4 {
#             background-color:  #babadb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col5 {
#             background-color:  #cfd0e6;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col6 {
#             background-color:  #e8e6f2;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col7 {
#             background-color:  #e2e2ef;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col8 {
#             background-color:  #cacae3;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col9 {
#             background-color:  #c9c9e2;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row0_col10 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col0 {
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col3 {
#             background-color:  #c4c5e0;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col4 {
#             background-color:  #babadb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col5 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col6 {
#             background-color:  #e7e6f1;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col7 {
#             background-color:  #f4f3f8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col8 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col9 {
#             background-color:  #cecee5;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row1_col10 {
#             background-color:  #8f8cc1;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col0 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col2 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col3 {
#             background-color:  #b5b5d7;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col4 {
#             background-color:  #cacae3;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col5 {
#             background-color:  #b6b6d8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col6 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col7 {
#             background-color:  #f5f3f8;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col8 {
#             background-color:  #b5b5d7;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col9 {
#             background-color:  #aeadd3;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row2_col10 {
#             background-color:  #e0e0ee;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col1 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col2 {
#             background-color:  #efedf5;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col5 {
#             background-color:  #a19eca;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col6 {
#             background-color:  #dcdcec;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col7 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col8 {
#             background-color:  #9a96c6;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col9 {
#             background-color:  #8a86bf;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row3_col10 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col0 {
#             background-color:  #f6f5f9;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col1 {
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col4 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col6 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col7 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col8 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col9 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row4_col10 {
#             background-color:  #aeadd3;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row5_col0 {
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row5_col1 {
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row5_col2 {
#             background-color:  #e0e0ee;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row5_col3 {
#             background-color:  #9490c3;
#             color:  #000000;
#         }    #T_e3e7635a_7042_11ea_b322_0242ac1c0002row5_col4 {
#             background-color:  #f1f0f6;
#             color:  #000000

# %% [markdown]
# **Explore Categorical variables**

# %%
# plot distribution

def stack_bar(df: pd.DataFrame, column: str):
    labels = []
    yes = []
    no = []

    yes_dict = dict(df[df['y'] == 1][column].value_counts())

    for key, value in yes_dict.items():
        labels.append(key)
        yes.append(value)
    
    for i in labels:
        no.append(dict(df[df[column] == i][df['y'] == 0][column].value_counts())[i])

    labels.reverse()
    yes.reverse()   
    no.reverse()    

    plt.figure(figsize=(6, 4))      
    plt.barh(labels, yes, color="#ffd159", label='Yes deposit')
    plt.barh(labels, no, left=yes, color="#5fb6c7", label='No deposit')

    plt.ylabel(f'{column}')
    plt.xlabel('Number of Clients')
    plt.title('Distribution of {} and deposit'.format(column))
    plt.legend()
    plt.show();

# %%
stack_bar(df, 'job'), stack_bar(df, 'marital'), stack_bar(df, 'education'), 
stack_bar(df, 'contact'), stack_bar(df, 'loan'), stack_bar(df, 'housing'), stack_bar(df, 'default')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (None, None, None, None)

# %% [markdown]
# # **Data Cleaning**

# %%
#change some of the categorical variables into binary variables
df.contact=df.contact.replace(to_replace=['cellular', 'telephone'], value=[1,0])
df.loan=df.loan.replace(to_replace=['yes', 'unknown','no'], value=[1,0,0])
df.housing=df.housing.replace(to_replace=['yes', 'unknown','no'],value=[1,0,0])
df.default=df.default.replace(to_replace=['yes', 'unknown','no'],value=[1,0,0])
df.poutcome=df.poutcome.replace(to_replace=['success', 'failure','nonexistent'],value=[1,0,0])

df.head()
# Out:
#    age        job  marital  ... euribor3m  nr.employed  y
# 0   56  housemaid  married  ...     4.857       5191.0  0
# 1   57   services  married  ...     4.857       5191.0  0
# 2   37   services  married  ...     4.857       5191.0  0
# 3   40     admin.  married  ...     4.857       5191.0  0
# 4   56   services  married  ...     4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
#dummy coding
df2=pd.get_dummies(df.job)
df2.head()
df3=pd.get_dummies(df.month)
df4=pd.get_dummies(df.day_of_week)
df5=pd.get_dummies(df.marital)
df6=pd.get_dummies(df.education)
df.drop(['job', 'month', 'day_of_week'], axis=1, inplace=True)

# %%
#Intergration of datasets
dfend=df.join(df2,how='left')
dfend2=dfend.join(df3,how="left")
dfend3=dfend2.join(df4,how="left")
dfend4=dfend3.join(df5,how="left",lsuffix='_emply',rsuffix='_marital')
dfend5=dfend4.join(df6,how="left")

dfend5.rename(columns={'unknown':'unknown_edu'}, inplace=True)
dfend5.head()
# Out:
#    age  marital  ... university.degree  unknown_edu
# 0   56  married  ...                 0            0
# 1   57  married  ...                 0            0
# 2   37  married  ...                 0            0
# 3   40  married  ...                 0            0
# 4   56  married  ...                 0            0
#
# [5 rows x 57 columns]

# %%
#drop encoded columns
data=dfend5.drop(columns=['marital','education','default'])
data.head()
# Out:
#    age  housing  loan  ...  professional.course  university.degree  unknown_edu
# 0   56        0     0  ...                    0                  0            0
# 1   57        0     0  ...                    0                  0            0
# 2   37        1     0  ...                    0                  0            0
# 3   40        0     0  ...                    0                  0            0
# 4   56        0     1  ...                    0                  0            0
#
# [5 rows x 54 columns]

# %% [markdown]
# # **Model Building**

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# **Grid Search for the Best Parameters**

# %%
#setup grid search
n_jobs=-1
random_state=100
cv = StratifiedKFold(shuffle=True, n_splits=5, random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(data, data.y, test_size=0.2)
X_train.drop('y', axis=1, inplace=True)
X_test.drop('y', axis=1, inplace=True)
pipe_rf = Pipeline([('rf', RandomForestClassifier(random_state=random_state, oob_score=True, n_jobs=n_jobs))])
grid_params_rf = [{
                'rf__criterion': ['entropy'],
                'rf__min_samples_leaf': [50, 150],
                'rf__max_depth': [22, 29],
                'rf__min_samples_split': [2, 9],
                'rf__n_estimators' : [50, 80]
                }]
gs_rf = GridSearchCV(pipe_rf, param_grid=grid_params_rf,
                     scoring='accuracy', cv=cv)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# **Train the random forest classifier**
#
# Achieved AUC-ROC of 0.94 and accuracy of 90%

# %%
#train model and show the result
gs_rf.fit(X_train,y_train)
auc = roc_auc_score(y_test, gs_rf.predict_proba(X_test)[:,1])
print(auc)
print(gs_rf.best_params_)
print(gs_rf.best_score_)
# Out:
# 0.9405766799964492
# {'rf__criterion': 'entropy', 'rf__max_depth': 29, 'rf__min_samples_leaf': 50, 'rf__min_samples_split': 2, 'rf__n_estimators': 50}
# 0.9077389984825492

# %%
#Save Model
import joblib
filename = 'Bank Marketing Model.sav'
joblib.dump(gs_rf, filename)
# Out:
# ['Bank Marketing Model.sav']

# %% [markdown]
# **Visualize important features**

# %%
import seaborn as sns
Feature_selection= RandomForestClassifier(criterion='entropy', random_state=11, oob_score=True, n_jobs=-1, \
                           max_depth=22, min_samples_leaf=50, min_samples_split=2, n_estimators=50)
Feature_selection.fit(X_train, y_train)
Features=pd.DataFrame(Feature_selection.feature_importances_, X_train.columns, columns=["feature"])
Features= Features.sort_values(by='feature', ascending=False).reset_index()
    
plt.figure(figsize=[6,6])
sns.barplot(x='index', y='feature', data=Features[:5], palette="GnBu_d")
plt.title('Feature inportance of RF Model')
plt.xticks(rotation=45)
plt.show();
